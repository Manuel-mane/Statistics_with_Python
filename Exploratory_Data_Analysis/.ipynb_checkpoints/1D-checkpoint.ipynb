# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import pandas as pd

# %%
d1 = np.loadtxt("./dataset/1D/example_1.txt")
d2 = np.loadtxt("./dataset/1D/example_2.txt")

print(d1.shape, d2.shape)
# Out:
# (500,) (500,)

# %% [markdown]
# # Histogram Plots

# %%
plt.figure(figsize=(10,8))
plt.hist(d1, label="D1")
plt.hist(d2, label="D2")
plt.legend()
plt.ylabel("Count");

# %% [markdown]
# **Improving the histogram**

# %%
plt.figure(figsize=(10,8))

bins = np.linspace(min(d1.min(), d2.min()), max(d1.max(), d2.max()), 50)
counts1, _,_ =  plt.hist(d1, bins=bins, label="D1")
plt.hist(d2, bins=bins, label="D2")
plt.legend()
plt.ylabel("Count");

# %%
plt.figure(figsize=(10,8))

bins = np.linspace(min(d1.min(), d2.min()), max(d1.max(), d2.max()), 50)
counts1, _,_ =  plt.hist(d1, bins=bins, label="D1", density=True)
plt.hist(d2, bins=bins, label="D2", density=True)
plt.legend()
plt.ylabel("Probability");

# %% [markdown]
# **Improving the visuals**

# %%
plt.figure(figsize=(10,8))

bins = np.linspace(min(d1.min(), d2.min()), max(d1.max(), d2.max()), 50)
counts1, _,_ =  plt.hist(d1, bins=bins, label="D1", histtype="step", density=True, lw=1)
plt.hist(d2, bins=bins, label="D2", density=True, histtype="step", ls=":")
plt.legend()
plt.ylabel("Count");

# %%
plt.figure(figsize=(10,8))

bins = np.linspace(min(d1.min(), d2.min()), max(d1.max(), d2.max()), 50)

plt.hist([d1,d2], bins=bins, label="Stacked", density=True,alpha=0.5)
plt.hist(d1, bins=bins, label="D1", density=True, histtype="step",  lw=1)
plt.hist(d2, bins=bins, label="D2", density=True, histtype="step", ls=":")
plt.legend()
plt.ylabel("Count");

# %%
# When we have multiple histograms it is better to set a fixed number of bins instead of standarizing with the minimum and 
# maximum of all of our data

plt.figure(figsize=(10,8))

bins = 50

plt.hist([d1,d2], bins=bins, label="Stacked", density=True,alpha=0.5)
plt.hist(d1, bins=bins, label="D1", density=True, histtype="step",  lw=1)
plt.hist(d2, bins=bins, label="D2", density=True, histtype="step", ls=":")
plt.legend()
plt.ylabel("Count");

# %% [markdown]
# # Bee Swarm Plots

# %%
# Formatting the data to one simple dataframe

dataset = pd.DataFrame({"value": np.concatenate((d1, d2)), 
                       "type": np.concatenate((np.ones(d1.shape), np.zeros(d2.shape)))})
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   value   1000 non-null   float64
#  1   type    1000 non-null   float64
# dtypes: float64(2)
# memory usage: 15.8 KB

# %%
sb.swarmplot(dataset["value"]);
# Out:
# C:\Users\manit\anaconda3\envs\Data_science\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\manit\anaconda3\envs\Data_science\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 16.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
plt.figure(figsize=(10,8))
sb.swarmplot(x="type", y="value", data=dataset, size=4);

# %% [markdown]
# # Box Plots

# %%
plt.figure(figsize=(10,8))
sb.boxplot(x="type", y = "value", data=dataset);
sb.swarmplot(x="type", y = "value", data=dataset, size=4, color='k', alpha=0.3);

# %% [markdown]
# # Violin Plot

# %%
plt.figure(figsize=(10,8))
sb.violinplot(x="type", y = "value", data=dataset);
sb.swarmplot(x="type", y = "value", data=dataset, size=4, color='k', alpha=0.3);

# %%
plt.figure(figsize=(10,8))
sb.violinplot(x="type", y = "value", data=dataset, inner="quartile", bw=0.2);
